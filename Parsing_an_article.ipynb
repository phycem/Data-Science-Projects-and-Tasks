# %% [markdown]
# <a href="https://colab.research.google.com/github/phycem/Data-Science-Projects-and-Tasks/blob/main/Parsing_an_article.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://youtu.be/2XUhKpH0p4M

# %% [markdown]
# https://www.geeksforgeeks.org/newspaper-article-scraping-curation-python/

# %%
pip install newspaper3k
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 211 kB 6.9 MB/s
# ...
#      |████████████████████████████████| 7.4 MB 21.2 MB/s
# ...
#      |████████████████████████████████| 81 kB 7.3 MB/s
# ...
#      |████████████████████████████████| 93 kB 930 kB/s
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13553 sha256=b990d3a113f7673e86d4f11f761985d4ec23d6db5b8da83ba96f9ad0e9592fab
#   Stored in directory: /root/.cache/pip/wheels/df/67/41/faca10fa501ca010be41b49d40360c2959e1c4f09bcbfa37fa
# ...
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3357 sha256=cac67ed619dc246d967bb570b154c1fa6966904d4c85a2583be03a7bc4e6bf53
#   Stored in directory: /root/.cache/pip/wheels/7f/d4/8f/6e2ca54744c9d7292d88ddb8d42876bcdab5e6d84a21c10346
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
list1=[url1,url2,url3]

# %%
url1="https://www.prnewswire.com/news-releases/upmc-childrens-hospital-foundation-receives-1-million-gift-from-alba-tull-to-benefit-childrens-neuroscience-institute-301529601.html"

# %%
url2="https://www.prnewswire.com/news-releases/sionna-therapeutics-launches-with-111-million-series-b-financing-to-advance-pipeline-of-novel-small-molecules-with-the-potential-to-fully-restore-cftr-function-in-cystic-fibrosis-301527741.html"

# %%
url3="https://www.prnewswire.com/news-releases/airwavz-secures-70m-credit-facility-with-ab-private-credit-investors-301530512.html"

# %%
from newspaper import Article

#A new article from TOI
#url = "https://www.prnewswire.com/news-releases/upmc-childrens-hospital-foundation-receives-1-million-gift-from-alba-tull-to-benefit-childrens-neuroscience-institute-301529601.html"

#For different language newspaper refer above table
for url in list1:
  toi_article = Article(url, language="en") # en for English

  #To download the article
  toi_article.download()

  #To parse the article
  toi_article.parse()

  #To perform natural language processing ie..nlp
  toi_article.nlp()



  print("Article's Title:")
  print(toi_article.title)
  print("n")

  article=toi_article.text
  doc= nlp(article)
  textwritten=nlp(toi_article.title)
  for ent in textwritten.ents:
    print(ent.text,"|",ent.label_,"|",spacy.explain(ent.label_))
    for ent in doc.ents:
      print(ent.text,"|",ent.label_,"|",spacy.explain(ent.label_))
# Out:
# Article's Title:
# UPMC Children's Hospital Foundation Receives $1 Million Gift from Alba Tull to Benefit Children's Neuroscience Institute
# n
# UPMC Children's Hospital Foundation Receives | ORG | Companies, agencies, institutions, etc.
# April 21, 2022 | DATE | Absolute or relative dates or periods
# Hospital Foundation | ORG | Companies, agencies, institutions, etc.
# today | DATE | Absolute or relative dates or periods
# $1 million | MONEY | Monetary values, including unit
# UPMC Children's Hospital of Pittsburgh's Children's Neuroscience Institute | ORG | Companies, agencies, institutions, etc.
# Pittsburgh | GPE | Countries, cities, states
# Last year | DATE | Absolute or relative dates or periods
# the University of Pittsburgh School of Medicine | ORG | Companies, agencies, institutions, etc.
# Center | ORG | Companies, agencies, institutions, etc.
# Today | DATE | Absolute or relative dates or periods
# The past few years | DATE | Absolute or relative dates or periods
# ...

# %%
import spacy
nlp=spacy.load("en_core_web_sm")

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
article=toi_article.text
doc= nlp(article)

# %%
textwritten=nlp(toi_article.title)

# %%
for ent in textwritten.ents:
  print(ent.text,"|",ent.label_,"|",spacy.explain(ent.label_))
# Out:
# 70 | MONEY | Monetary values, including unit

# %%
from spacy.matcher import Matcher

# %%
#initialize matcher
matcher = Matcher(nlp.vocab)

# Create a pattern matching two tokens: "Alice" and a Verb
#TEXT is for the exact match and VERB for a verb
pattern = [{"TEXT": "ORG"}, {"POS": "by"}]


# Add the pattern to the matcher

#the first variable is a unique id for the pattern (alice).
#The second is an optional callback and the third one is our pattern.
matcher.add("ORG", [pattern])

# Use the matcher on the doc
matches = matcher(textwritten)
print("Matches:", [textwritten[start:end].text for match_id, start, end in matches])
# Out:
# Matches: []

# %%
matcher = Matcher(nlp.vocab)
pattern = [{"LEMMA": "ORG"},{"POS": "ADP"}]
matcher.add("id1", [pattern])
matches = matcher(textwritten)
print("Matches:", set([textwritten[start:end].text for match_id, start, end in matches]))
# Out:
# Matches: set()

# %%
for ent in doc.ents:
  print(ent.text,"|",ent.label_,"|",spacy.explain(ent.label_))
# Out:
# CHARLOTTE | ORG | Companies, agencies, institutions, etc.
# N.C. | GPE | Countries, cities, states
# April 21, 2022 | DATE | Absolute or relative dates or periods
# Airwavz Solutions, Inc. | ORG | Companies, agencies, institutions, etc.
# today | DATE | Absolute or relative dates or periods
# AB Private Credit Investors | ORG | Companies, agencies, institutions, etc.
# AllianceBernstein | PERSON | People, including fictional
# the past few years | DATE | Absolute or relative dates or periods
# AllianceBernstein | ORG | Companies, agencies, institutions, etc.
# Airwavz CFO | PERSON | People, including fictional
# Shawn Kocher | PERSON | People, including fictional
# Enhanced Communication Abilities | ORG | Companies, agencies, institutions, etc.
# recent years | DATE | Absolute or relative dates or periods
# Airwavz | ORG | Companies, agencies, institutions, etc.
# DAS | ORG | Companies, agencies, institutions, etc.
# one | CARDINAL | Numerals that do not fall under another type
# ...
